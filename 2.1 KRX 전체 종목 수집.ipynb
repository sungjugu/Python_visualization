# %% [markdown]
# # FinanceDataReader 란?
# * 한국 주식 가격, 미국 주식 가격, 지수, 환욜, 암호화폐 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리

# %% [markdown]
# # 설치

# %%
pip install -U finance-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 라이브러리 불러오기

# %%
import pandas as pd

# %%
import FinanceDataReader as fdr

# %%
fdr.__version__
# Out:
# '0.9.33'

# %% [markdown]
# # 한국거래소 상장종목 전체 가져오기

# %%
df_krx = fdr.StockListing("KRX")

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx.shape #(행,열) 크기
# Out:
# (8273, 10)

# %%
# 전체 데이터프레임의 요약정보
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8273 entries, 0 to 8272
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          8273 non-null   object
#  1   Market          8273 non-null   object
#  2   Name            8273 non-null   object
#  3   Sector          2499 non-null   object
#  4   Industry        2482 non-null   object
#  5   ListingDate     2499 non-null   datetime64[ns]
#  6   SettleMonth     2499 non-null   object
#  7   Representative  2499 non-null   object
#  8   HomePage        2347 non-null   object
#  9   Region          2499 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 711.0+ KB

# %%
df_krx.describe()
# Out:
# /var/folders/6y/x7mscwfj5v1glksbx09ymx2m0000gn/T/ipykernel_12318/2191770547.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_krx.describe()
#         Symbol Market  Name          Sector Industry          ListingDate  \
# count     8273   8273  8273            2499     2482                 2499
# unique    8273      3  8273             161     2327                 1858
# top     060310  KOSPI    3S  소프트웨어 개발 및 공급업   기업인수합병  1976-06-30 00:00:00
# freq         1   6575     1             151       29                    8
# first      NaN    NaN   NaN             NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN   NaN             NaN      NaN  2022-05-26 00:00:00
#
#        SettleMonth Representative               HomePage Region
# ...

# %% [markdown]
# # 파일로 저장하고 불러오기

# %%
df_krx.to_csv("krx.csv", index=False)

# %%
pd.read_csv("krx.csv")
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 8268  003280   KOSPI             흥아해운                    해상 운송업
# 8269  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 8270  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 8271  429870   KOSPI    히어로즈 리츠이지스액티브                       NaN
# 8272  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...
